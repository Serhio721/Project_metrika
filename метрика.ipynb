# %%
import pandas as pd
import pyreadstat


df, meta = pyreadstat.read_sav('данные по индивидам за 2011.sav')

# %%
#REGION - 138 - Москва
#REGION - 141 - Санкт-Петербург

table = df[df['region'].isin([138, 141])]

# %%
len(table)
# Out:
# 1755

# %%
df_itog = table[['p_educ', 'p_diplom_1', 'ph5', 'p_age', 'pj1.1.3', 'pj1.1.4']]

# %%
df_itog
# Out:
#        p_educ  p_diplom_1  ph5  p_age  pj1.1.3  pj1.1.4
# 2326     21.0         6.0  2.0   73.0      NaN      NaN
# 2327     21.0         6.0  1.0   43.5      3.0      2.0
# 2328     21.0         6.0  2.0   43.0      NaN      NaN
# 3761     21.0         6.0  2.0   70.0      NaN      NaN
# 3762     21.0         6.0  2.0   45.5      4.0      3.0
# ...       ...         ...  ...    ...      ...      ...
# 17010    18.0         5.0  2.0   66.0      NaN      NaN
# 17011    14.0         4.0  2.0   71.5      NaN      NaN
# 17012    20.0         5.0  2.0   32.0      1.0      2.0
# 17017    14.0         4.0  1.0   62.0      3.0      4.0
# 17018    21.0         6.0  2.0   27.0      2.0      1.0
#
# [1755 rows x 6 columns]
